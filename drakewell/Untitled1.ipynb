# %%
import pandas as pd
import matplotlib.pyplot as plt

index1 = ['2017-07-01','2017-07-01','2017-07-02','2017-07-02','2017-07-03','2017-07-03','2017-07-03']
index2 = pd.to_datetime(index1,format='%Y-%m-%d')

df = pd.DataFrame([[123456],[123789],[123654],[654321],[654987],[789456],[789123]],columns=['Count'],index=index2)

# %%
df.index
# Out:
# DatetimeIndex(['2017-07-01', '2017-07-01', '2017-07-02', '2017-07-02',
#                '2017-07-03', '2017-07-03', '2017-07-03'],
#               dtype='datetime64[ns]', freq=None)

# %%
df.boxplot(by=df.index.date, column='Count', figsize=(15,7))
